# %% [markdown]
# # Predicting Length of Stay - Data EDA
# Xiaoyu Yang
# <br>
# Created on 4/7/24

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 2000)
pd.options.mode.copy_on_write = True

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import datetime

# %% [markdown]
# ### Initial inspection of the overall structure of data
# Observations from an initial inspection:
# 1. The data seems to be pulling from four sources: clients, appointments, episode of care (EOC), and providers
# 2. The data seems to be at client + appointment level, but the prediction is at client level. There should be some aggregation of information at client level
# 3. There is not a unique identifier for clients. I need to create one
# 4. There is not an existing target column in the data. I need to create a target variable using appointment data using the combination of appointment dates, appointment status and discharge status
# 5. Some columns have wrong data types. I need to correct them for further processing to create modeling-ready data set
# 6. There are test rows in the data. I need to exclude them from any EDA or modeling

# %%
df = pd.read_csv('./data/analytics_case_study_raw_data (3).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9100 entries, 0 to 9099
# Data columns (total 69 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   APPOINTMENT_ID_PRIMARY_KEY                                9100 non-null   int64
#  1   APPOINTMENT_DESCRIPTION_LOW_LEVEL_X                       9100 non-null   object
#  2   APPOINTMENT_DATE_X                                        9100 non-null   object
#  3   APPOINTMENT_ATTENDANCE_STATUS_NAME_X                      9100 non-null   object
#  4   EOC_KEY_X                                                 9100 non-null   int64
#  5   APPOINTMENT_DESCRIPTION_HIGH_LEVEL_X                      9100 non-null   object
#  6   Assigned PT                                               9100 non-null   object
#  7   Assigned CS                                               9100 non-null   object
#  8   Assigned CD                                               9100 non-null   object
#  9   EOC_SALESFORCE_OPPORTUNITY_ID_CRM                         9100 non-null   object
#  10  EOC_INTERESTED_IN_FAMILY_THERAPY_CRM                      8719 non-null   object
#  11  EOC_FAMILY_THERAPY_SCHEDULED_DURING_BPS_CRM               9100 non-null   object
#  12  EOC_FAMILY_THERAPY_NOT_SCHEDULED_DURING_BPS_REASON_CRM    1323 non-null   object
#  13  EOC_SCHEDULED_INDIVIDUAL_THERAPY_HOURS_PRODUCT            9100 non-null   int64
#  14  EOC_SCHEDULED_FAMILY_THERAPY_HOURS_PRODUCT                9100 non-null   int64
#  15  EOC_REFERRAL_SOURCE_TYPE_CRM                              7830 non-null   object
#  16  EOC_REFERRAL_SOURCE_SUBTYPE_CRM                           2428 non-null   object
#  17  EOC_REFERRAL_SOURCE_STATE_CRM                             7655 non-null   object
#  18  EOC_OUTREACH_REFERRAL_OWNER_CRM                           8373 non-null   object
#  19  EOC_HAS_CARE_CENTER_ACCESS_PRODUCT                        9100 non-null   bool
#  20  EOC_NUMBER_OF_CARE_CENTER_ACCOUNTS_WITH_ACCESS_PRODUCT    9100 non-null   int64
#  21  CLIENT_DATE_OF_BIRTH_CRM                                  9100 non-null   object
#  22  CLIENT_RACE_ETHNICITY_NAME_CRM                            9100 non-null   object
#  23  CLIENT_RELIGION_NAME_CRM                                  9091 non-null   object
#  24  CLIENT_PREFERRED_LANGUAGE_CRM                             8998 non-null   object
#  25  CLIENT_GENDER_CRM                                         9007 non-null   object
#  26  CLIENT_PREFERRED_PRONOUN_CRM                              9093 non-null   object
#  27  CLIENT_PREFERRED_NAME_IS_SAFE_CRM                         9100 non-null   bool
#  28  CLIENT_REFERRAL_SOURCE_CONTACT_NAME_CRM                   7579 non-null   object
#  29  CLIENT_SEX_EHR                                            9100 non-null   object
#  30  EOC_PROGRAM_TYPE_MH_OR_SUD_CRM                            9041 non-null   object
#  31  EOC_OPPORTUNITY_CONFIRMED_LEAD_SOURCE_TYPE_CRM            9040 non-null   object
#  32  EOC_PAYMENT_PLAN_IS_NEEDED_CRM                            9100 non-null   bool
#  33  EOC_ADMISSION_PENDING_REASON_CRM                          1353 non-null   object
#  34  EOC_REASON_FOR_DISCHARGE_CRM                              8733 non-null   object
#  35  CLIENT_ACCOUNT_SOURCE_TYPE_CRM                            9100 non-null   object
#  36  CLIENT_ACCOUNT_TYPE_NAME_CRM                              9100 non-null   object
#  37  CLIENT_ACCOUNT_IS_TEST_ACCOUNT_CRM                        9100 non-null   bool
#  38  EOC_PROGRAM_AND_CARE_GROUP_CODE_PRODUCT                   9100 non-null   object
#  39  EOC_CARE_GROUP_CODE_PRODUCT                               9100 non-null   object
#  40  EOC_CARE_PROGRAM_ADOL_VS_YA_PRODUCT                       9100 non-null   object
#  41  EOC_INSURANCE_PRIMARY_OR_SECONDARY_CRM                    9100 non-null   object
#  42  EOC_INSURANCE_PLAN_TYPE_CRM                               9100 non-null   object
#  43  EOC_INSURANCE_PAYOR_TYPE_CRM                              9021 non-null   object
#  44  EOC_INSURANCE_PLAN_NAME_CRM                               9100 non-null   object
#  45  EOC_INSURANCE_CARRIER_NAME_CRM                            9100 non-null   object
#  46  CLIENT_STATE_CODE_X                                       9100 non-null   object
#  47  CLIENT_ADDRESS_LINE1_X                                    8987 non-null   object
#  48  CLIENT_CITY_X                                             9100 non-null   object
#  49  CLIENT_ZIP_CODE_X                                         9076 non-null   float64
#  50  CLIENT_COUNTRY_X                                          9100 non-null   object
#  51  CLIENT_COUNTRY_CODE_X                                     9067 non-null   object
#  52  CLIENT_PHONE_X                                            9084 non-null   object
#  53  CLIENT_EMAIL_X                                            9100 non-null   object
#  54  CLIENT_FULL_NAME_NO_PREFERRED_NAME_X                      9100 non-null   object
#  55  CLIENT_FULL_NAME_WITH_PREFERRED_NAME_X                    9100 non-null   object
#  56  Appointment provider                                      9100 non-null   object
#  57  Appointment provider supervisor                           9100 non-null   object
#  58  Appointment Provider Race                                 8692 non-null   object
#  59  Appointment Provider employment type                      8692 non-null   object
#  60  Appointment Provider Charlie Health tenure (years)        8692 non-null   float64
#  61  Appointment Provider Years of experience (years)          8692 non-null   float64
#  62  Appointment Provider Gender                               8692 non-null   object
#  63  Assigned Primary Therapist Race                           9100 non-null   object
#  64  Assigned Primary Therapist employment type                9100 non-null   object
#  65  Assigned Primary Therapist Charlie Health tenure (years)  9100 non-null   int64
#  66  Assigned Primary Therapist Years of experience (years)    9100 non-null   int64
#  67  Assigned Primary Therapist Gender                         9100 non-null   object
#  68  Session Notes                                             6930 non-null   object
# dtypes: bool(4), float64(3), int64(7), object(55)
# memory usage: 4.5+ MB

# %%
df.isnull().sum()
# Out:
# APPOINTMENT_ID_PRIMARY_KEY                                     0
# APPOINTMENT_DESCRIPTION_LOW_LEVEL_X                            0
# APPOINTMENT_DATE_X                                             0
# APPOINTMENT_ATTENDANCE_STATUS_NAME_X                           0
# EOC_KEY_X                                                      0
# APPOINTMENT_DESCRIPTION_HIGH_LEVEL_X                           0
# Assigned PT                                                    0
# Assigned CS                                                    0
# Assigned CD                                                    0
# EOC_SALESFORCE_OPPORTUNITY_ID_CRM                              0
# EOC_INTERESTED_IN_FAMILY_THERAPY_CRM                         381
# EOC_FAMILY_THERAPY_SCHEDULED_DURING_BPS_CRM                    0
# EOC_FAMILY_THERAPY_NOT_SCHEDULED_DURING_BPS_REASON_CRM      7777
# EOC_SCHEDULED_INDIVIDUAL_THERAPY_HOURS_PRODUCT                 0
# EOC_SCHEDULED_FAMILY_THERAPY_HOURS_PRODUCT                     0
# EOC_REFERRAL_SOURCE_TYPE_CRM                                1270
# EOC_REFERRAL_SOURCE_SUBTYPE_CRM                             6672
# EOC_REFERRAL_SOURCE_STATE_CRM                               1445
# EOC_OUTREACH_REFERRAL_OWNER_CRM                              727
# EOC_HAS_CARE_CENTER_ACCESS_PRODUCT                             0
# EOC_NUMBER_OF_CARE_CENTER_ACCOUNTS_WITH_ACCESS_PRODUCT         0
# CLIENT_DATE_OF_BIRTH_CRM                                       0
# CLIENT_RACE_ETHNICITY_NAME_CRM                                 0
# CLIENT_RELIGION_NAME_CRM                                       9
# CLIENT_PREFERRED_LANGUAGE_CRM                                102
# CLIENT_GENDER_CRM                                             93
# CLIENT_PREFERRED_PRONOUN_CRM                                   7
# CLIENT_PREFERRED_NAME_IS_SAFE_CRM                              0
# CLIENT_REFERRAL_SOURCE_CONTACT_NAME_CRM                     1521
# CLIENT_SEX_EHR                                                 0
# EOC_PROGRAM_TYPE_MH_OR_SUD_CRM                                59
# EOC_OPPORTUNITY_CONFIRMED_LEAD_SOURCE_TYPE_CRM                60
# EOC_PAYMENT_PLAN_IS_NEEDED_CRM                                 0
# EOC_ADMISSION_PENDING_REASON_CRM                            7747
# EOC_REASON_FOR_DISCHARGE_CRM                                 367
# CLIENT_ACCOUNT_SOURCE_TYPE_CRM                                 0
# CLIENT_ACCOUNT_TYPE_NAME_CRM                                   0
# CLIENT_ACCOUNT_IS_TEST_ACCOUNT_CRM                             0
# EOC_PROGRAM_AND_CARE_GROUP_CODE_PRODUCT                        0
# EOC_CARE_GROUP_CODE_PRODUCT                                    0
# EOC_CARE_PROGRAM_ADOL_VS_YA_PRODUCT                            0
# EOC_INSURANCE_PRIMARY_OR_SECONDARY_CRM                         0
# EOC_INSURANCE_PLAN_TYPE_CRM                                    0
# EOC_INSURANCE_PAYOR_TYPE_CRM                                  79
# EOC_INSURANCE_PLAN_NAME_CRM                                    0
# EOC_INSURANCE_CARRIER_NAME_CRM                                 0
# CLIENT_STATE_CODE_X                                            0
# CLIENT_ADDRESS_LINE1_X                                       113
# CLIENT_CITY_X                                                  0
# CLIENT_ZIP_CODE_X                                             24
# CLIENT_COUNTRY_X                                               0
# CLIENT_COUNTRY_CODE_X                                         33
# CLIENT_PHONE_X                                                16
# CLIENT_EMAIL_X                                                 0
# CLIENT_FULL_NAME_NO_PREFERRED_NAME_X                           0
# CLIENT_FULL_NAME_WITH_PREFERRED_NAME_X                         0
# Appointment provider                                           0
# Appointment provider supervisor                                0
# Appointment Provider Race                                    408
# Appointment Provider employment type                         408
# Appointment Provider Charlie Health tenure (years)           408
# Appointment Provider Years of experience (years)             408
# Appointment Provider Gender                                  408
# Assigned Primary Therapist Race                                0
# Assigned Primary Therapist employment type                     0
# Assigned Primary Therapist Charlie Health tenure (years)       0
# Assigned Primary Therapist Years of experience (years)         0
# Assigned Primary Therapist Gender                              0
# Session Notes                                               2170
# dtype: int64

# %%
df.head()
# Out:
#    APPOINTMENT_ID_PRIMARY_KEY APPOINTMENT_DESCRIPTION_LOW_LEVEL_X  \
# 0                           0                       Group Session
# 1                           2                       Group Session
# 2                           4                       Group Session
# 3                           5                  Individual Session
# 4                           6                       Group Session
#
#   APPOINTMENT_DATE_X APPOINTMENT_ATTENDANCE_STATUS_NAME_X  EOC_KEY_X  \
# 0         12/19/2023                             Attended   11138868
# 1          1/15/2024                           Incomplete   10422996
# 2         11/15/2023                             Attended   11893825
# 3         10/27/2023                             Attended   10998829
# 4          11/7/2023                             Attended   10171953
#
#   APPOINTMENT_DESCRIPTION_HIGH_LEVEL_X Assigned PT Assigned CS Assigned CD  \
# 0                                  IOP       PT 34        CS 7        CD 3
# 1                                  IOP       PT 22        CS 5        CD 2
# 2                                  IOP       PT 42        CS 9        CD 3
# 3                                  OPT       PT 31        CS 7        CD 3
# 4                                  IOP       PT 16        CS 4        CD 2
#
#   EOC_SALESFORCE_OPPORTUNITY_ID_CRM EOC_INTERESTED_IN_FAMILY_THERAPY_CRM  \
# 0                       208-39-8583                                False
# 1                       819-55-7947                                 True
# 2                       873-76-1907                                 True
# 3                       111-45-9869                                 True
# 4                       873-35-4511                                 True
#
#   EOC_FAMILY_THERAPY_SCHEDULED_DURING_BPS_CRM  \
# 0                                       FALSE
# 1                                       FALSE
# 2                                       FALSE
# 3                                       FALSE
# 4                                       FALSE
#
#   EOC_FAMILY_THERAPY_NOT_SCHEDULED_DURING_BPS_REASON_CRM  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    EOC_SCHEDULED_INDIVIDUAL_THERAPY_HOURS_PRODUCT  \
# 0                                               1
# 1                                               1
# 2                                               1
# 3                                               1
# 4                                               1
#
#    EOC_SCHEDULED_FAMILY_THERAPY_HOURS_PRODUCT EOC_REFERRAL_SOURCE_TYPE_CRM  \
# 0                                           0          Outpatient Practice
# 1                                           1          Outpatient Practice
# 2                                           0                          NaN
# 3                                           0                     Hospital
# 4                                           0                          PCP
#
#   EOC_REFERRAL_SOURCE_SUBTYPE_CRM EOC_REFERRAL_SOURCE_STATE_CRM  \
# 0                             NaN                      Arkansas
# 1                             NaN                     Minnesota
# 2                 Hospital System                     Minnesota
# 3                             NaN                      Michigan
# 4                             NaN                     Minnesota
#
#   EOC_OUTREACH_REFERRAL_OWNER_CRM  EOC_HAS_CARE_CENTER_ACCESS_PRODUCT  \
# 0                    Andi Vilaboy                                True
# 1                  Amanda Davison                                True
# 2                        D Becker                                True
# 3                  Clare Robinson                                True
# 4                   Hillary Wylie                                True
#
#    EOC_NUMBER_OF_CARE_CENTER_ACCOUNTS_WITH_ACCESS_PRODUCT  \
# 0                                                  1
# 1                                                  0
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#   CLIENT_DATE_OF_BIRTH_CRM CLIENT_RACE_ETHNICITY_NAME_CRM  \
# 0                5/18/2001                          White
# 1               11/21/2009                          White
# 2                 6/5/2000                     Other Race
# 3                4/23/2001                          White
# 4                2/25/2008                          White
#
#    CLIENT_RELIGION_NAME_CRM CLIENT_PREFERRED_LANGUAGE_CRM CLIENT_GENDER_CRM  \
# 0  No Religious Affiliation                       English            Female
# 1  No Religious Affiliation                       English            Female
# 2              Christianity                       English        Non-Binary
# 3  No Religious Affiliation                       Spanish       Transgender
# 4  No Religious Affiliation                       English            Female
#
#   CLIENT_PREFERRED_PRONOUN_CRM  CLIENT_PREFERRED_NAME_IS_SAFE_CRM  \
# 0                       He/Him                              False
# 1                       He/Him                              False
# 2                      She/Her                              False
# 3                    They/Them                              False
# 4                      She/Her                               True
#
#   CLIENT_REFERRAL_SOURCE_CONTACT_NAME_CRM CLIENT_SEX_EHR  \
# 0                          Sean Gutierrez              F
# 1                             Victor Bass              M
# 2                                     NaN         Female
# 3                                     NaN              M
# 4                          Patrick Dawson              F
#
#   EOC_PROGRAM_TYPE_MH_OR_SUD_CRM  \
# 0                  Mental Health
# 1                  Mental Health
# 2                  Mental Health
# 3                  Mental Health
# 4                  Mental Health
#
#   EOC_OPPORTUNITY_CONFIRMED_LEAD_SOURCE_TYPE_CRM  \
# 0                          Professional Referral
# 1                                       Internet
# 2                          Professional Referral
# 3                          Professional Referral
# 4                          Professional Referral
#
#    EOC_PAYMENT_PLAN_IS_NEEDED_CRM EOC_ADMISSION_PENDING_REASON_CRM  \
# 0                           False                              NaN
# 1                           False                              NaN
# 2                           False                              NaN
# 3                           False   Pending PCP Referral;PA Needed
# 4                           False                              NaN
#
#                 EOC_REASON_FOR_DISCHARGE_CRM  \
# 0                                    Routine
# 1                                    Routine
# 2                                    Routine
# 3  Routine with exception (poor program fit)
# 4                                    Routine
#
#        CLIENT_ACCOUNT_SOURCE_TYPE_CRM CLIENT_ACCOUNT_TYPE_NAME_CRM  \
# 0               Professional Referral             Client - Patient
# 1                            Internet             Client - Patient
# 2  Professional Referral - Revalidate             Client - Patient
# 3               Professional Referral             Client - Patient
# 4  Professional Referral - Revalidate             Client - Patient
#
#    CLIENT_ACCOUNT_IS_TEST_ACCOUNT_CRM EOC_PROGRAM_AND_CARE_GROUP_CODE_PRODUCT  \
# 0                               False                             ADOL-DLGO17
# 1                               False                             ADOL-CFTO24
# 2                               False                              ADOL-POCY2
# 3                               False                              ADOL-CFTO4
# 4                                True                            ADOL-CFTYY12
#
#   EOC_CARE_GROUP_CODE_PRODUCT EOC_CARE_PROGRAM_ADOL_VS_YA_PRODUCT  \
# 0                       DGO79                                ADOL
# 1                       DGY55                                ADOL
# 2                       DGO43                                  YA
# 3                        GNY5                                  YA
# 4                       DGO50                                ADOL
#
#   EOC_INSURANCE_PRIMARY_OR_SECONDARY_CRM EOC_INSURANCE_PLAN_TYPE_CRM  \
# 0                                Primary                         PPO
# 1                                Primary                          OA
# 2                                Primary                         OA+
# 3                                Primary                         HMO
# 4                                Primary                         PPO
#
#   EOC_INSURANCE_PAYOR_TYPE_CRM EOC_INSURANCE_PLAN_NAME_CRM  \
# 0                   Commercial              Randall Miller
# 1                   Commercial               Pamela Horton
# 2                   Commercial                   Amy Brown
# 3                   Commercial                 Sherry Hale
# 4                     Medicaid                 Carl Bowers
#
#   EOC_INSURANCE_CARRIER_NAME_CRM CLIENT_STATE_CODE_X  \
# 0                Jennifer Kramer              Oregon
# 1                 Melissa Newton            Virginia
# 2                 Caroline Dixon             Alabama
# 3                     Sarah Ford            Kentucky
# 4                   Rita Salazar        Pennsylvania
#
#           CLIENT_ADDRESS_LINE1_X CLIENT_CITY_X  CLIENT_ZIP_CODE_X  \
# 0   21109 Barrera Hills Apt. 884   Powersmouth            79517.0
# 1             711 Mclaughlin Via      Hillfort            25045.0
# 2              669 Williams Fort    Brownmouth            51288.0
# 3  7417 Barrett Valleys Apt. 659    Lake Stacy            16126.0
# 4     90930 Hughes Mall Apt. 624   Douglastown            98077.0
#
#   CLIENT_COUNTRY_X CLIENT_COUNTRY_CODE_X       CLIENT_PHONE_X  \
# 0    United States                    ID         507.622.8033
# 1    United States                    GR         242-447-4376
# 2    United States                    PE  +1-974-547-9409x551
# 3    United States                    SG           3128880770
# 4    United States                    HR   642-897-3850x55504
#
#               CLIENT_EMAIL_X CLIENT_FULL_NAME_NO_PREFERRED_NAME_X  \
# 0      berrydawn@example.com                          Karen Perez
# 1    nicholeking@example.org                   Nicholas Mccormick
# 2   gregoryevans@example.net                          Dale Bowers
# 3  cristianburns@example.net                          Joan Sparks
# 4       xkrueger@example.org                 Mr. Jimmy Esparza MD
#
#   CLIENT_FULL_NAME_WITH_PREFERRED_NAME_X  Appointment provider  \
# 0                          Timothy Smith  Group Facilitator 31
# 1                       Benjamin Jackson   Group Facilitator 1
# 2                           Nancy Turner  Group Facilitator 38
# 3                      Jonathan Morrison                 PT 31
# 4                         Jill Avila PhD  Group Facilitator 14
#
#   Appointment provider supervisor Appointment Provider Race  \
# 0              Group Supervisor 7                     White
# 1              Group Supervisor 1                     White
# 2              Group Supervisor 8                     Asian
# 3                            CS 7                     White
# 4              Group Supervisor 3                Other Race
#
#   Appointment Provider employment type  \
# 0                                 1099
# 1                                 1099
# 2                                 1099
# 3                   employee_full_time
# 4                                 1099
#
#    Appointment Provider Charlie Health tenure (years)  \
# 0                                                1.0
# 1                                                0.0
# 2                                                1.0
# 3                                                1.0
# 4                                                0.0
#
#    Appointment Provider Years of experience (years)  \
# 0                                               9.0
# 1                                               2.0
# 2                                               6.0
# 3                                               6.0
# 4                                               7.0
#
#   Appointment Provider Gender Assigned Primary Therapist Race  \
# 0                        Male                         unknown
# 1                      Female                      Other Race
# 2                      Female              Hispanic or Latino
# 3                        Male                           White
# 4                        Male                           White
#
#   Assigned Primary Therapist employment type  \
# 0                         employee_full_time
# 1                         employee_full_time
# 2                                       1099
# 3                         employee_full_time
# 4                         employee_part_time
#
#    Assigned Primary Therapist Charlie Health tenure (years)  \
# 0                                                  1
# 1                                                  2
# 2                                                  0
# 3                                                  1
# 4                                                  1
#
#    Assigned Primary Therapist Years of experience (years)  \
# 0                                                  4
# 1                                                 10
# 2                                                  5
# 3                                                  6
# 4                                                  4
#
#   Assigned Primary Therapist Gender  \
# 0                              Male
# 1                              Male
# 2                            Female
# 3                              Male
# 4                            Female
#
#                                        Session Notes
# 0  The session revolved around the client's anxie...
# 1                                                NaN
# 2  The session revolved around the client's ongoi...
# 3  During our session, the client discussed feeli...
# 4  The client and I delved into their recent expe...

# %% [markdown]
# ### Data processing
# I will first probe into the data by each source and create aggregated features either within the data source or across different data sources

# %%
# filter data for non-test records
df = df[df['CLIENT_ACCOUNT_IS_TEST_ACCOUNT_CRM'] == False].reset_index()

# create a client_id using client email + birthday
df['client_id'] = df['CLIENT_EMAIL_X'].astype('str') + df['CLIENT_DATE_OF_BIRTH_CRM'].astype('str')
df['CLIENT_DATE_OF_BIRTH_CRM'] = pd.to_datetime(df['CLIENT_DATE_OF_BIRTH_CRM'])
df['APPOINTMENT_DATE_X'] = pd.to_datetime(df['APPOINTMENT_DATE_X'])

# %%
# split the dataset into 4 subsets for more efficient data EDA
cli_cols = [col for col in df.columns if col.startswith('CLIENT')]
app_cols = [col for col in df.columns if col.startswith('APPOINTMENT')]
eoc_cols = [col for col in df.columns if col.startswith('EOC')]
prd_cols = [col for col in df.columns if col not in cli_cols + app_cols + eoc_cols + ['client_id']]

cli = df[['client_id'] + cli_cols + prd_cols]
app = df[['client_id'] + app_cols + eoc_cols]

# %%
df.APPOINTMENT_DATE_X.min(), df.APPOINTMENT_DATE_X.max()
# Out:
# (Timestamp('2023-10-01 00:00:00'), Timestamp('2024-03-05 00:00:00'))

# %%
(df.APPOINTMENT_DATE_X.max() - df.APPOINTMENT_DATE_X.min()) // np.timedelta64(1, 'W')
# Out:
# 22

# %% [markdown]
# #### Client data EDA
# 1. Probe into demographic features such as age, gender, religion, language preferences and source of referral
# 2. For geographic features, they may be useful when combined with other data sources. More to explore later

# %%
# Although there are 8633 records at client and appointment level, there are only 887 unique clients, and they can be captured by client email + birthday. I created a client_id with client email + birthday (in string format)
cli.shape, cli.drop_duplicates().shape, cli.drop_duplicates(subset = ['CLIENT_EMAIL_X', 'CLIENT_DATE_OF_BIRTH_CRM']).shape
# Out:
# ((8633, 40), (8633, 40), (887, 40))

# %%
cli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8633 entries, 0 to 8632
# Data columns (total 40 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   client_id                                                 8633 non-null   object
#  1   CLIENT_DATE_OF_BIRTH_CRM                                  8633 non-null   datetime64[ns]
#  2   CLIENT_RACE_ETHNICITY_NAME_CRM                            8633 non-null   object
#  3   CLIENT_RELIGION_NAME_CRM                                  8624 non-null   object
#  4   CLIENT_PREFERRED_LANGUAGE_CRM                             8531 non-null   object
#  5   CLIENT_GENDER_CRM                                         8540 non-null   object
#  6   CLIENT_PREFERRED_PRONOUN_CRM                              8633 non-null   object
#  7   CLIENT_PREFERRED_NAME_IS_SAFE_CRM                         8633 non-null   bool
#  8   CLIENT_REFERRAL_SOURCE_CONTACT_NAME_CRM                   7249 non-null   object
#  9   CLIENT_SEX_EHR                                            8633 non-null   object
#  10  CLIENT_ACCOUNT_SOURCE_TYPE_CRM                            8633 non-null   object
#  11  CLIENT_ACCOUNT_TYPE_NAME_CRM                              8633 non-null   object
#  12  CLIENT_ACCOUNT_IS_TEST_ACCOUNT_CRM                        8633 non-null   bool
#  13  CLIENT_STATE_CODE_X                                       8633 non-null   object
#  14  CLIENT_ADDRESS_LINE1_X                                    8520 non-null   object
#  15  CLIENT_CITY_X                                             8633 non-null   object
#  16  CLIENT_ZIP_CODE_X                                         8609 non-null   float64
#  17  CLIENT_COUNTRY_X                                          8633 non-null   object
#  18  CLIENT_COUNTRY_CODE_X                                     8600 non-null   object
#  19  CLIENT_PHONE_X                                            8617 non-null   object
#  20  CLIENT_EMAIL_X                                            8633 non-null   object
#  21  CLIENT_FULL_NAME_NO_PREFERRED_NAME_X                      8633 non-null   object
#  22  CLIENT_FULL_NAME_WITH_PREFERRED_NAME_X                    8633 non-null   object
#  23  index                                                     8633 non-null   int64
#  24  Assigned PT                                               8633 non-null   object
#  25  Assigned CS                                               8633 non-null   object
#  26  Assigned CD                                               8633 non-null   object
#  27  Appointment provider                                      8633 non-null   object
#  28  Appointment provider supervisor                           8633 non-null   object
#  29  Appointment Provider Race                                 8252 non-null   object
#  30  Appointment Provider employment type                      8252 non-null   object
#  31  Appointment Provider Charlie Health tenure (years)        8252 non-null   float64
#  32  Appointment Provider Years of experience (years)          8252 non-null   float64
#  33  Appointment Provider Gender                               8252 non-null   object
#  34  Assigned Primary Therapist Race                           8633 non-null   object
#  35  Assigned Primary Therapist employment type                8633 non-null   object
#  36  Assigned Primary Therapist Charlie Health tenure (years)  8633 non-null   int64
#  37  Assigned Primary Therapist Years of experience (years)    8633 non-null   int64
#  38  Assigned Primary Therapist Gender                         8633 non-null   object
#  39  Session Notes                                             6582 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(3), object(31)
# memory usage: 2.5+ MB

# %%
cli.isnull().sum()
# Out:
# client_id                                                      0
# CLIENT_DATE_OF_BIRTH_CRM                                       0
# CLIENT_RACE_ETHNICITY_NAME_CRM                                 0
# CLIENT_RELIGION_NAME_CRM                                       9
# CLIENT_PREFERRED_LANGUAGE_CRM                                102
# CLIENT_GENDER_CRM                                             93
# CLIENT_PREFERRED_PRONOUN_CRM                                   0
# CLIENT_PREFERRED_NAME_IS_SAFE_CRM                              0
# CLIENT_REFERRAL_SOURCE_CONTACT_NAME_CRM                     1384
# CLIENT_SEX_EHR                                                 0
# CLIENT_ACCOUNT_SOURCE_TYPE_CRM                                 0
# CLIENT_ACCOUNT_TYPE_NAME_CRM                                   0
# CLIENT_ACCOUNT_IS_TEST_ACCOUNT_CRM                             0
# CLIENT_STATE_CODE_X                                            0
# CLIENT_ADDRESS_LINE1_X                                       113
# CLIENT_CITY_X                                                  0
# CLIENT_ZIP_CODE_X                                             24
# CLIENT_COUNTRY_X                                               0
# CLIENT_COUNTRY_CODE_X                                         33
# CLIENT_PHONE_X                                                16
# CLIENT_EMAIL_X                                                 0
# CLIENT_FULL_NAME_NO_PREFERRED_NAME_X                           0
# CLIENT_FULL_NAME_WITH_PREFERRED_NAME_X                         0
# index                                                          0
# Assigned PT                                                    0
# Assigned CS                                                    0
# Assigned CD                                                    0
# Appointment provider                                           0
# Appointment provider supervisor                                0
# Appointment Provider Race                                    381
# Appointment Provider employment type                         381
# Appointment Provider Charlie Health tenure (years)           381
# Appointment Provider Years of experience (years)             381
# Appointment Provider Gender                                  381
# Assigned Primary Therapist Race                                0
# Assigned Primary Therapist employment type                     0
# Assigned Primary Therapist Charlie Health tenure (years)       0
# Assigned Primary Therapist Years of experience (years)         0
# Assigned Primary Therapist Gender                              0
# Session Notes                                               2051
# dtype: int64

# %%
# give the correct data type to birthday and zip code columns
cli['CLIENT_DATE_OF_BIRTH_CRM'] = pd.to_datetime(cli['CLIENT_DATE_OF_BIRTH_CRM'])
cli['CLIENT_ZIP_CODE_X'] = cli['CLIENT_ZIP_CODE_X'].apply(lambda x: "{:.0f}".format(x) if not pd.isnull(x) else x).astype('str').apply(lambda x: x.zfill(5))

# %%
# calculate age using the current date
cli['age'] = (datetime.datetime.today() - cli.CLIENT_DATE_OF_BIRTH_CRM) // np.timedelta64(1, 'Y')

# %%
# EHR is the most reliable source of gender, but it is also useful to create a flag to indicate if the client has special gender identity
cli.groupby('CLIENT_SEX_EHR').client_id.nunique()
# Out:
# CLIENT_SEX_EHR
# F                 442
# Female             68
# Intersex/Other      3
# M                 248
# Male               25
# N                  74
# Unknown            27
# Name: client_id, dtype: int64

# %%
cli.groupby('CLIENT_GENDER_CRM').client_id.nunique()
# Out:
# CLIENT_GENDER_CRM
# Female                                      511
# Gender Fluid                                  3
# Gender Neutral                               29
# Genderqueer Gender Nonconforming Neither      7
# Male                                        286
# Non-Binary                                   21
# Other                                         1
# Transgender                                  17
# Name: client_id, dtype: int64

# %%
cli.groupby(['CLIENT_SEX_EHR', 'CLIENT_GENDER_CRM']).client_id.nunique()
# Out:
# CLIENT_SEX_EHR  CLIENT_GENDER_CRM
# F               Female                                      310
#                 Gender Neutral                                5
#                 Genderqueer Gender Nonconforming Neither      3
#                 Male                                        119
#                 Non-Binary                                    1
#                 Other                                         1
#                 Transgender                                   1
# Female          Female                                       30
#                 Gender Fluid                                  2
#                 Gender Neutral                                4
#                 Male                                         19
#                 Non-Binary                                    8
#                 Transgender                                   2
# Intersex/Other  Female                                        1
#                 Male                                          2
# M               Female                                      136
#                 Gender Neutral                                9
#                 Genderqueer Gender Nonconforming Neither      2
#                 Male                                         84
#                 Non-Binary                                    5
#                 Transgender                                   6
# Male            Female                                        6
#                 Gender Neutral                                2
#                 Genderqueer Gender Nonconforming Neither      2
#                 Male                                         11
#                 Non-Binary                                    1
#                 Transgender                                   3
# N               Female                                       22
#                 Gender Fluid                                  1
#                 Gender Neutral                                5
#                 Male                                         38
#                 Non-Binary                                    5
#                 Transgender                                   3
# Unknown         Female                                        6
#                 Gender Neutral                                4
#                 Male                                         13
#                 Non-Binary                                    1
#                 Transgender                                   2
# Name: client_id, dtype: int64

# %%
cli['gender'] = np.where(
    (cli.CLIENT_SEX_EHR.isin(['F', 'Female'])) & ((cli.CLIENT_GENDER_CRM) == 'Female'), 'Female', np.where(
        (cli.CLIENT_SEX_EHR.isin(['M', 'Male'])) & ((cli.CLIENT_GENDER_CRM) == 'Male'), 'Male', 'Special'
    )
)

# %%
# Pick top 2 ethinicies and create a race feature with less levels
cli.groupby('CLIENT_RACE_ETHNICITY_NAME_CRM').client_id.nunique()
# Out:
# CLIENT_RACE_ETHNICITY_NAME_CRM
# 2 or more                                     40
# American Indian or Alaska Native               7
# Asian                                         14
# Black or African American                    125
# Hispanic or Latino                             1
# Native Hawaiian or Other Pacific Islander      3
# Other Race                                    98
# White                                        597
# unknown                                        2
# Name: client_id, dtype: int64

# %%
cli['race'] = np.where(
    cli.CLIENT_RACE_ETHNICITY_NAME_CRM == 'White', 'White', np.where(
        cli.CLIENT_RACE_ETHNICITY_NAME_CRM == 'Black or Africa America', 'Black', 'Other'
    )
)

# %%
# Create a binary variable to indicate if a client has religious belief
cli.groupby('CLIENT_RELIGION_NAME_CRM').client_id.nunique()
# Out:
# CLIENT_RELIGION_NAME_CRM
# Agnostic                     11
# Atheist                       4
# Baptist                       5
# Buddhism                      4
# Catholic                     35
# Christianity                166
# Episcopal                    41
# Hinduism                      1
# Jehova's Witness              4
# Jewish                       21
# Judaism                       2
# Lutheran                      1
# Mormon                        5
# Muslim                        2
# No Religious Affiliation    562
# Nondenominational            11
# Pagan                         3
# Protestant                    3
# Unknown Religion              4
# Unstated Religion             1
# Name: client_id, dtype: int64

# %%
cli['religion_ind'] = np.where(cli.CLIENT_RELIGION_NAME_CRM == 'No Religious Affiliation', 'N', 'Y')

# %%
# Create a binary feature to indicate if a client prefers Spanish
cli.groupby('CLIENT_PREFERRED_LANGUAGE_CRM').client_id.nunique()
# Out:
# CLIENT_PREFERRED_LANGUAGE_CRM
# English    843
# Spanish     37
# Name: client_id, dtype: int64

# %%
cli['spanish_ind'] = np.where(cli.CLIENT_PREFERRED_LANGUAGE_CRM == 'Spanish', 'Y', 'N')

# %%
# combine the processed columns for modeling. Below are the demographic variables for modeling. I will examine geographic features later
df_cli = cli[['client_id', 'age', 'gender', 'race', 'religion_ind', 'spanish_ind']]

# %%
df_cli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8633 entries, 0 to 8632
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   client_id     8633 non-null   object
#  1   age           8633 non-null   int64
#  2   gender        8633 non-null   object
#  3   race          8633 non-null   object
#  4   religion_ind  8633 non-null   object
#  5   spanish_ind   8633 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 404.8+ KB

# %%
df_cli.describe()
# Out:
#                age
# count  8633.000000
# mean     20.082358
# std       4.368966
# min      12.000000
# 25%      17.000000
# 50%      20.000000
# 75%      23.000000
# max      34.000000

# %% [markdown]
# #### Appointment + EOC data EDA

# %%
app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8633 entries, 0 to 8632
# Data columns (total 32 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   client_id                                               8633 non-null   object
#  1   APPOINTMENT_ID_PRIMARY_KEY                              8633 non-null   int64
#  2   APPOINTMENT_DESCRIPTION_LOW_LEVEL_X                     8633 non-null   object
#  3   APPOINTMENT_DATE_X                                      8633 non-null   datetime64[ns]
#  4   APPOINTMENT_ATTENDANCE_STATUS_NAME_X                    8633 non-null   object
#  5   APPOINTMENT_DESCRIPTION_HIGH_LEVEL_X                    8633 non-null   object
#  6   EOC_KEY_X                                               8633 non-null   int64
#  7   EOC_SALESFORCE_OPPORTUNITY_ID_CRM                       8633 non-null   object
#  8   EOC_INTERESTED_IN_FAMILY_THERAPY_CRM                    8264 non-null   object
#  9   EOC_FAMILY_THERAPY_SCHEDULED_DURING_BPS_CRM             8633 non-null   object
#  10  EOC_FAMILY_THERAPY_NOT_SCHEDULED_DURING_BPS_REASON_CRM  1261 non-null   object
#  11  EOC_SCHEDULED_INDIVIDUAL_THERAPY_HOURS_PRODUCT          8633 non-null   int64
#  12  EOC_SCHEDULED_FAMILY_THERAPY_HOURS_PRODUCT              8633 non-null   int64
#  13  EOC_REFERRAL_SOURCE_TYPE_CRM                            7462 non-null   object
#  14  EOC_REFERRAL_SOURCE_SUBTYPE_CRM                         2288 non-null   object
#  15  EOC_REFERRAL_SOURCE_STATE_CRM                           7265 non-null   object
#  16  EOC_OUTREACH_REFERRAL_OWNER_CRM                         7928 non-null   object
#  17  EOC_HAS_CARE_CENTER_ACCESS_PRODUCT                      8633 non-null   bool
#  18  EOC_NUMBER_OF_CARE_CENTER_ACCOUNTS_WITH_ACCESS_PRODUCT  8633 non-null   int64
#  19  EOC_PROGRAM_TYPE_MH_OR_SUD_CRM                          8574 non-null   object
#  20  EOC_OPPORTUNITY_CONFIRMED_LEAD_SOURCE_TYPE_CRM          8573 non-null   object
#  21  EOC_PAYMENT_PLAN_IS_NEEDED_CRM                          8633 non-null   bool
#  22  EOC_ADMISSION_PENDING_REASON_CRM                        1280 non-null   object
#  23  EOC_REASON_FOR_DISCHARGE_CRM                            8278 non-null   object
#  24  EOC_PROGRAM_AND_CARE_GROUP_CODE_PRODUCT                 8633 non-null   object
#  25  EOC_CARE_GROUP_CODE_PRODUCT                             8633 non-null   object
#  26  EOC_CARE_PROGRAM_ADOL_VS_YA_PRODUCT                     8633 non-null   object
#  27  EOC_INSURANCE_PRIMARY_OR_SECONDARY_CRM                  8633 non-null   object
#  28  EOC_INSURANCE_PLAN_TYPE_CRM                             8633 non-null   object
#  29  EOC_INSURANCE_PAYOR_TYPE_CRM                            8573 non-null   object
#  30  EOC_INSURANCE_PLAN_NAME_CRM                             8633 non-null   object
#  31  EOC_INSURANCE_CARRIER_NAME_CRM                          8633 non-null   object
# dtypes: bool(2), datetime64[ns](1), int64(5), object(24)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Provider data EDA

# %% [markdown]
# ### Create and save the modeling-ready data set
# Before any further data EDA between the target variable and eligible features, I'll randomly split 20% of data into a test set and set it aside. This set will be used to evaluate the model on out samples
